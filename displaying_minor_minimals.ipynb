# %% [markdown]
# # Displaying the connected minor-minimal graphs on at most 10 vertices for a given spectator number
#
# ### Use the read_minor_minimals() function to get the minimals_dict from the GitHub repo. The main function to use is display_connected_minimal_graphs(spec_num, minimals_dict), where spec_num is a number between 0 and 8.
#
# ### Warning: There are 121 such graphs for spectator number 5, 417 for spectator number 6, and 1155 for spectator number 7

# %%
load('spectator_floor_display_functions.py')

# %%
minimals_dict = read_minor_minimals()

# %%
for spec_key in minimals_dict.keys():
    spec_num = spec_key.split('_')[0]
    print(f'Number of connected minor-minimal graphs on at most 10 vertices with {spec_num} spectators: {len(minimals_dict.get(spec_key))}')
# Out:
# Number of connected minor-minimal graphs on at most 10 vertices with 0 spectators: 1
# Number of connected minor-minimal graphs on at most 10 vertices with 1 spectators: 2
# Number of connected minor-minimal graphs on at most 10 vertices with 2 spectators: 4
# Number of connected minor-minimal graphs on at most 10 vertices with 3 spectators: 10
# Number of connected minor-minimal graphs on at most 10 vertices with 4 spectators: 35
# Number of connected minor-minimal graphs on at most 10 vertices with 5 spectators: 121
# Number of connected minor-minimal graphs on at most 10 vertices with 6 spectators: 417
# Number of connected minor-minimal graphs on at most 10 vertices with 7 spectators: 1155
# Number of connected minor-minimal graphs on at most 10 vertices with 8 spectators: 2
# Number of connected minor-minimal graphs on at most 10 vertices with 9 spectators: 0

# %%
display_connected_minimal_graphs(0, minimals_dict)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
display_connected_minimal_graphs(1, minimals_dict)
# Out:
# Graphics Array of size 1 x 2

# %%
display_connected_minimal_graphs(2, minimals_dict)
# Out:
# Graphics Array of size 1 x 3
# Graphics object consisting of 14 graphics primitives

# %%
display_connected_minimal_graphs(3, minimals_dict)
# Out:
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics object consisting of 12 graphics primitives

# %%
display_connected_minimal_graphs(4, minimals_dict)
# Out:
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 3
# Graphics Array of size 1 x 2

# %%
display_connected_minimal_graphs(5, minimals_dict)
# Out:
# ...
# are you sure you want to proceed?
# Enter 'Yes' to print all 121 of the graphs.
#  no

# %%
display_connected_minimal_graphs(8, minimals_dict)
# Out:
# Graphics Array of size 1 x 2
